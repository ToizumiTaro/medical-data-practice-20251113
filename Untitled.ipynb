# %%
import pandas as pd

df = pd.read_csv("sample.csv")
df
# Out:
#    patient_id  age  value        date
# 0           1   34    5.4  2024-01-01
# 1           2   58    7.1  2024-01-02
# 2           3   42    4.9  2024-01-02
# 3           4   33    9.0  2024-01-03
# 4           5   59    6.2  2024-01-03

# %%
df.describe()
# Out:
#        patient_id        age     value
# count    5.000000   5.000000  5.000000
# mean     3.000000  45.200000  6.520000
# std      1.581139  12.637247  1.617714
# min      1.000000  33.000000  4.900000
# 25%      2.000000  34.000000  5.400000
# 50%      3.000000  42.000000  6.200000
# 75%      4.000000  58.000000  7.100000
# max      5.000000  59.000000  9.000000

# %%
import matplotlib.pyplot as plt

df["value"].hist()
plt.show()
